% %%
A=[1,2;3,4]
% Out:
% A =
%    1   2
%    3   4

% %%
B=[5,6;7,8]
% Out:
% B =
%    5   6
%    7   8

% %%
A+B
% Out:
% ans =
%     6    8
%    10   12

% %%
A

% %%
C=[4,5;6,7]
% Out:
% C =
%    4   5
%    6   7

% %%
t = linspace(0,6*pi,100);
plot(sin(t))
grid on
hold on
plot(cos(t), 'r')

% %%
x=1:1.8:10
% Out:
% x =
%      1.0000     2.8000     4.6000     6.4000     8.2000    10.0000

% %%
plot(sin(x))

% %%
b = 10*cos(t)+30; plot(b); grid on

% %%
x=0:1:0
% Out:
% x = 0

% %%
plot(tan(x))

% %%
plot(sin(x))

% %%
y=linspace(0,100)
% Out:
% y =
%  Columns 1 through 6:
%      0.00000     1.01010     2.02020     3.03030     4.04040     5.05051
%  Columns 7 through 12:
%      6.06061     7.07071     8.08081     9.09091    10.10101    11.11111
%  Columns 13 through 18:
%     12.12121    13.13131    14.14141    15.15152    16.16162    17.17172
%  Columns 19 through 24:
%     18.18182    19.19192    20.20202    21.21212    22.22222    23.23232
%  Columns 25 through 30:
%     24.24242    25.25253    26.26263    27.27273    28.28283    29.29293
%  Columns 31 through 36:
%     30.30303    31.31313    32.32323    33.33333    34.34343    35.35354
%  Columns 37 through 42:
%     36.36364    37.37374    38.38384    39.39394    40.40404    41.41414
%  Columns 43 through 48:
%     42.42424    43.43434    44.44444    45.45455    46.46465    47.47475
%  Columns 49 through 54:
%     48.48485    49.49495    50.50505    51.51515    52.52525    53.53535
%  Columns 55 through 60:
% ...

% %%
plot(sin(y))

% %%
y= linspace(0,199)
% Out:
% y =
%  Columns 1 through 6:
%      0.00000     2.01010     4.02020     6.03030     8.04040    10.05051
%  Columns 7 through 12:
%     12.06061    14.07071    16.08081    18.09091    20.10101    22.11111
%  Columns 13 through 18:
%     24.12121    26.13131    28.14141    30.15152    32.16162    34.17172
%  Columns 19 through 24:
%     36.18182    38.19192    40.20202    42.21212    44.22222    46.23232
%  Columns 25 through 30:
%     48.24242    50.25253    52.26263    54.27273    56.28283    58.29293
%  Columns 31 through 36:
%     60.30303    62.31313    64.32323    66.33333    68.34343    70.35354
%  Columns 37 through 42:
%     72.36364    74.37374    76.38384    78.39394    80.40404    82.41414
%  Columns 43 through 48:
%     84.42424    86.43434    88.44444    90.45455    92.46465    94.47475
%  Columns 49 through 54:
%     96.48485    98.49495   100.50505   102.51515   104.52525   106.53535
%  Columns 55 through 60:
% ...

% %%
plot(tan(y))

% %%
a1=
[225.512 2.64537 0.00201692
225.512  2.64537 0.00201692
226.94   1.59575 0.00225557
226.94   1.59575 0.00225557
227.31   1.70513 0.002282
227.31   1.70513 0.002282
227.729  5.34308 0.00205535
227.729  5.34308 0.00205535
227.975  5.12741 0.001822
227.975  5.12741 0.001822]
% Out:
% parse error:
%   syntax error
% >>> a1=
%        ^

% %%
a1=
[225.512:2.64537:0.00201692]

% %%
a1

% %%
a1=225.512:2.64537:0.00201692
% Out:
% a1 = [](1x0)

% %%
a1
% Out:
% a1 = [](1x0)

% %%
a1=100;
a2=2323;
a3=212
% Out:
% a3 =  212

% %%
[X, Y] = meshgrid(linspace(10,15,2), linspace(0,5,2));
Z = griddata(a1,a2,a3,X,Y);
Z(isnan(Z)) = 0;
imshow(Z)
% Out:
% error: griddata: A(I,J): column index out of bounds; value 2 out of bound 1
% error: called from
%     griddata at line 109 column 8

% %%
a1=10

% %%
a1

% %%
5+6
% Out:
% ans =  11

% %%
2^6
% Out:
% ans =  64

% %%
1~=2 % false
% Out:
% ans =  1

% %%
1~=2 % True
% Out:
% ans =  1

% %%
xor(1,0)
% Out:
% ans =  1

% %%
1||0
% Out:
% ans =  1

% %%
0&&0
% Out:
% ans = 0

% %%
c='df';

% %%
c
% Out:
% c = df

% %%
A=[1 2;3 4]
% Out:
% A =
%    1   2
%    3   4

% %%
pinv(A)
% Out:
% ans =
%   -2.00000   1.00000
%    1.50000  -0.50000

% %%
A'
% Out:
% ans =
%    1   3
%    2   4

% %%
randn(1,10)
% Out:
% ans =
%  Columns 1 through 8:
%    0.49794  -1.13363  -0.54648  -1.35071   2.39533  -1.03212   1.72849   0.11546
%  Columns 9 and 10:
%    0.42988   0.89920

% %%
w = -6+sqrt(10)*randn(1,10)
% Out:
% w =
%  Columns 1 through 8:
%   -3.4303  -7.6917  -9.6623  -5.5920  -6.2652  -1.6012  -7.2834  -3.1297
%  Columns 9 and 10:
%   -9.2200  -3.6674

% %%
hist(w)

% %%
w = -6+sqrt(10)*randn(1,1000)
% Out:
% Columns 109 through 114:
%   -2.2018e+000  -6.4018e+000  -2.6939e+000  -7.2263e+000  -8.5767e+000  -5.0464e+000
%  Columns 115 through 120:
%   1.3991e+000  -3.1889e+000  -5.9308e+000  -4.9946e+000  -8.8574e+000  -5.9032e+000
%  Columns 121 through 126:
%   -1.3244e-001  -1.7456e+000  -9.7513e+000  -3.1059e+000  -5.0541e+000  -1.0480e+001
%  Columns 127 through 132:
%   -7.0792e+000  -7.1074e+000  -4.2379e+000  -2.4328e+000  -3.8404e+000  -7.2253e+000
%  Columns 133 through 138:
%   -5.7351e+000  -4.4982e+000  -6.9313e+000  -4.8768e+000  -1.2155e+001  -9.2343e+000
%  Columns 139 through 144:
%   -9.1534e+000  -5.2386e+000  -1.0761e-001  -5.4235e+000  -5.3549e+000  -4.7254e+000
%  Columns 145 through 150:
%   -1.0796e+001  -9.8931e+000  -1.0063e+001  -7.2723e+000  -5.2458e+000  -2.2285e+000
%  Columns w =
%  Columns 1 through 6:
%   -7.0459e+000  -6.7343e+000  -3.7309e+000  -7.8582e+000  -8.5251e+000  -2.7394e+000
%  Columns 7 through 12:
% ...

% %%
hist(w,50)
